# %% [markdown]
# <a href="https://colab.research.google.com/github/Luzius11/Youtube2023/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nelgiriyewithana/global-youtube-statistics-2023")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 60.1k/60.1k [00:00<00:00, 11.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/nelgiriyewithana/global-youtube-statistics-2023/versions/1

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/root/.cache/kagglehub/datasets/nelgiriyewithana/global-youtube-statistics-2023/versions/1'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /root/.cache/kagglehub/datasets/nelgiriyewithana/global-youtube-statistics-2023/versions/1/Global YouTube Statistics.csv

# %%
# to be able to see all columns in dataframe:
pd.set_option('display.max_columns', None)

#import Data
df = pd.read_csv('/root/.cache/kagglehub/datasets/nelgiriyewithana/global-youtube-statistics-2023/versions/1/Global YouTube Statistics.csv', encoding = 'latin-1')

# %%
df.head(50)
# Out:
#     rank                                           Youtuber  subscribers  \
# 0      1                                           T-Series    245000000
# 1      2                                     YouTube Movies    170000000
# 2      3                                            MrBeast    166000000
# 3      4                         Cocomelon - Nursery Rhymes    162000000
# 4      5                                          SET India    159000000
# 5      6                                              Music    119000000
# 6      7                                ýýý Kids Diana Show    112000000
# 7      8                                          PewDiePie    111000000
# 8      9                                        Like Nastya    106000000
# 9     10                                      Vlad and Niki     98900000
# 10    11                                  Zee Music Company     96700000
# 11    12                                                WWE     96000000
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')
